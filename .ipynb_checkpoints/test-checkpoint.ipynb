# %% [markdown]
# # テスト
#
# * Author: 黒木 玄
# * Date: 2018-03-13

# %% [markdown]
# ## コード

# %%
using Plots

# %%
plot(sin)

# %% [markdown]
# ## 説明

# %% [markdown]
# ガンマ函数とベータ函数を
#
# $$
# \begin{aligned}
# & \Gamma(s) = \int_0^\infty e^{-x} x^{s-1}\,dx,
# \\
# & B(p,q) = \int_0^1 x^{p-1}(1-x)^{q-1}\,dx
# \end{aligned}
# $$
#
# と定義する.
